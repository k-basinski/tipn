# %%
import pandas as pd

# %%
narko = pd.read_csv('drugs.csv')

# %%
type(narko)
# Out:
# pandas.core.frame.DataFrame

# %%
narko
# Out:
#       age     n  alcohol-use  alcohol-frequency  marijuana-use  \
# 0      12  2798          3.9                3.0            1.1
# 1      13  2757          8.5                6.0            3.4
# 2      14  2792         18.1                5.0            8.7
# 3      15  2956         29.2                6.0           14.5
# 4      16  3058         40.1               10.0           22.5
# 5      17  3038         49.3               13.0           28.0
# 6      18  2469         58.7               24.0           33.7
# 7      19  2223         64.6               36.0           33.4
# 8      20  2271         69.7               48.0           34.0
# 9      21  2354         83.2               52.0           33.0
# 10  22-23  4707         84.2               52.0           28.4
# 11  24-25  4591         83.1               52.0           24.9
# 12  26-29  2628         80.7               52.0           20.8
# 13  30-34  2864         77.5               52.0           16.4
# ...

# %%
narko.head()
# Out:
#   age     n  alcohol-use  alcohol-frequency  marijuana-use  \
# 0  12  2798          3.9                3.0            1.1
# 1  13  2757          8.5                6.0            3.4
# 2  14  2792         18.1                5.0            8.7
# 3  15  2956         29.2                6.0           14.5
# 4  16  3058         40.1               10.0           22.5
#
#    marijuana-frequency  cocaine-use  cocaine-frequency  crack-use  \
# 0                  4.0          0.1                5.0        0.0
# 1                 15.0          0.1                1.0        0.0
# 2                 24.0          0.1                5.5        0.0
# 3                 25.0          0.5                4.0        0.1
# 4                 30.0          1.0                7.0        0.0
#
#    crack-frequency         ...          oxycontin-use  oxycontin-frequency  \
# 0              NaN         ...                    0.1                 24.5
# ...

# %%
narko.tail()
# Out:
#       age     n  alcohol-use  alcohol-frequency  marijuana-use  \
# 12  26-29  2628         80.7               52.0           20.8
# 13  30-34  2864         77.5               52.0           16.4
# 14  35-49  7391         75.0               52.0           10.4
# 15  50-64  3923         67.2               52.0            7.3
# 16    65+  2448         49.3               52.0            1.2
#
#     marijuana-frequency  cocaine-use  cocaine-frequency  crack-use  \
# 12                 52.0          3.2                5.0        0.4
# 13                 72.0          2.1                8.0        0.5
# 14                 48.0          1.5               15.0        0.5
# 15                 52.0          0.9               36.0        0.4
# 16                 36.0          0.0                NaN        0.0
#
#     crack-frequency         ...          oxycontin-use  oxycontin-frequency  \
# 12              6.0         ...                    1.2                 13.5
# ...

# %%
narko.tail(10)
# Out:
#       age     n  alcohol-use  alcohol-frequency  marijuana-use  \
# 7      19  2223         64.6               36.0           33.4
# 8      20  2271         69.7               48.0           34.0
# 9      21  2354         83.2               52.0           33.0
# 10  22-23  4707         84.2               52.0           28.4
# 11  24-25  4591         83.1               52.0           24.9
# 12  26-29  2628         80.7               52.0           20.8
# 13  30-34  2864         77.5               52.0           16.4
# 14  35-49  7391         75.0               52.0           10.4
# 15  50-64  3923         67.2               52.0            7.3
# 16    65+  2448         49.3               52.0            1.2
#
#     marijuana-frequency  cocaine-use  cocaine-frequency  crack-use  \
# 7                  60.0          4.1                5.5        0.5
# 8                  60.0          4.9                8.0        0.6
# 9                  52.0          4.8                5.0        0.5
# ...

# %%
narko.tail(2)
# Out:
#       age     n  alcohol-use  alcohol-frequency  marijuana-use  \
# 15  50-64  3923         67.2               52.0            7.3
# 16    65+  2448         49.3               52.0            1.2
#
#     marijuana-frequency  cocaine-use  cocaine-frequency  crack-use  \
# 15                 52.0          0.9               36.0        0.4
# 16                 36.0          0.0                NaN        0.0
#
#     crack-frequency         ...          oxycontin-use  oxycontin-frequency  \
# 15             62.0         ...                    0.4                  5.0
# 16              NaN         ...                    0.0                  NaN
#
#     tranquilizer-use  tranquilizer-frequency  stimulant-use  \
# 15               1.4                    10.0            0.3
# 16               0.2                     5.0            0.0
#
#     stimulant-frequency  meth-use  meth-frequency  sedative-use  \
# 15                 24.0       0.2            30.0           0.2
# ...

# %%
narko.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 28 columns):
# age                        17 non-null object
# n                          17 non-null int64
# alcohol-use                17 non-null float64
# alcohol-frequency          17 non-null float64
# marijuana-use              17 non-null float64
# marijuana-frequency        17 non-null float64
# cocaine-use                17 non-null float64
# cocaine-frequency          16 non-null float64
# crack-use                  17 non-null float64
# crack-frequency            14 non-null float64
# heroin-use                 17 non-null float64
# heroin-frequency           16 non-null float64
# hallucinogen-use           17 non-null float64
# hallucinogen-frequency     17 non-null float64
# inhalant-use               17 non-null float64
# inhalant-frequency         16 non-null float64
# pain-releiver-use          17 non-null float64
# pain-releiver-frequency    17 non-null float64
# ...

# %%
narko['age']
# Out:
# 0        12
# 1        13
# 2        14
# 3        15
# 4        16
# 5        17
# 6        18
# 7        19
# 8        20
# 9        21
# 10    22-23
# 11    24-25
# 12    26-29
# 13    30-34
# 14    35-49
# 15    50-64
# 16      65+
# Name: age, dtype: object

# %%
narko['alcohol-use']
# Out:
# 0      3.9
# 1      8.5
# 2     18.1
# 3     29.2
# 4     40.1
# 5     49.3
# 6     58.7
# 7     64.6
# 8     69.7
# 9     83.2
# 10    84.2
# 11    83.1
# 12    80.7
# 13    77.5
# 14    75.0
# 15    67.2
# 16    49.3
# Name: alcohol-use, dtype: float64

# %%
narko['n']
# Out:
# 0     2798
# 1     2757
# 2     2792
# 3     2956
# 4     3058
# 5     3038
# 6     2469
# 7     2223
# 8     2271
# 9     2354
# 10    4707
# 11    4591
# 12    2628
# 13    2864
# 14    7391
# 15    3923
# 16    2448
# Name: n, dtype: int64

# %%
a = [1, 2, 3]

# %%
a
# Out:
# [1, 2, 3]

# %%
s = ['ala', 'ma', 'kota']

# %%
s[0]
# Out:
# 'ala'

# %%
s[1]
# Out:
# 'ma'

# %%
narko.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 28 columns):
# age                        17 non-null object
# n                          17 non-null int64
# alcohol-use                17 non-null float64
# alcohol-frequency          17 non-null float64
# marijuana-use              17 non-null float64
# marijuana-frequency        17 non-null float64
# cocaine-use                17 non-null float64
# cocaine-frequency          16 non-null float64
# crack-use                  17 non-null float64
# crack-frequency            14 non-null float64
# heroin-use                 17 non-null float64
# heroin-frequency           16 non-null float64
# hallucinogen-use           17 non-null float64
# hallucinogen-frequency     17 non-null float64
# inhalant-use               17 non-null float64
# inhalant-frequency         16 non-null float64
# pain-releiver-use          17 non-null float64
# pain-releiver-frequency    17 non-null float64
# ...

# %%
narko[['age', 'meth-use', 'meth-frequency']]
# Out:
#       age  meth-use  meth-frequency
# 0      12       0.0             NaN
# 1      13       0.1             5.0
# 2      14       0.1            24.0
# 3      15       0.3            10.5
# 4      16       0.3            36.0
# 5      17       0.6            48.0
# 6      18       0.5            12.0
# 7      19       0.4           105.0
# 8      20       0.9            12.0
# 9      21       0.6             2.0
# 10  22-23       0.6            46.0
# 11  24-25       0.7            21.0
# 12  26-29       0.6            30.0
# 13  30-34       0.4            54.0
# 14  35-49       0.2           104.0
# 15  50-64       0.2            30.0
# 16    65+       0.0             NaN

# %%
narko[['age','heroin-use', 'heroin-frequency']]
# Out:
#       age  heroin-use  heroin-frequency
# 0      12         0.1              35.5
# 1      13         0.0               NaN
# 2      14         0.1               2.0
# 3      15         0.2               1.0
# 4      16         0.1              66.5
# 5      17         0.1              64.0
# 6      18         0.4              46.0
# 7      19         0.5             180.0
# 8      20         0.9              45.0
# 9      21         0.6              30.0
# 10  22-23         1.1              57.5
# 11  24-25         0.7              88.0
# 12  26-29         0.6              50.0
# 13  30-34         0.4              66.0
# 14  35-49         0.1             280.0
# 15  50-64         0.1              41.0
# 16    65+         0.0             120.0

# %%
s
# Out:
# ['ala', 'ma', 'kota']

# %%
s[0:3]
# Out:
# ['ala', 'ma', 'kota']

# %%
narko[0:3]
# Out:
#   age     n  alcohol-use  alcohol-frequency  marijuana-use  \
# 0  12  2798          3.9                3.0            1.1
# 1  13  2757          8.5                6.0            3.4
# 2  14  2792         18.1                5.0            8.7
#
#    marijuana-frequency  cocaine-use  cocaine-frequency  crack-use  \
# 0                  4.0          0.1                5.0        0.0
# 1                 15.0          0.1                1.0        0.0
# 2                 24.0          0.1                5.5        0.0
#
#    crack-frequency         ...          oxycontin-use  oxycontin-frequency  \
# 0              NaN         ...                    0.1                 24.5
# 1              3.0         ...                    0.1                 41.0
# 2              NaN         ...                    0.4                  4.5
#
#    tranquilizer-use  tranquilizer-frequency  stimulant-use  \
# 0               0.2                    52.0            0.2
# ...

# %%
narko[4:7]
# Out:
#   age     n  alcohol-use  alcohol-frequency  marijuana-use  \
# 4  16  3058         40.1               10.0           22.5
# 5  17  3038         49.3               13.0           28.0
# 6  18  2469         58.7               24.0           33.7
#
#    marijuana-frequency  cocaine-use  cocaine-frequency  crack-use  \
# 4                 30.0          1.0                7.0        0.0
# 5                 36.0          2.0                5.0        0.1
# 6                 52.0          3.2                5.0        0.4
#
#    crack-frequency         ...          oxycontin-use  oxycontin-frequency  \
# 4              1.0         ...                    1.1                  4.0
# 5             21.0         ...                    1.4                  6.0
# 6             10.0         ...                    1.7                  7.0
#
#    tranquilizer-use  tranquilizer-frequency  stimulant-use  \
# 4               2.4                    11.0            1.8
# ...

# %%
narko[7:10]
# Out:
#   age     n  alcohol-use  alcohol-frequency  marijuana-use  \
# 7  19  2223         64.6               36.0           33.4
# 8  20  2271         69.7               48.0           34.0
# 9  21  2354         83.2               52.0           33.0
#
#    marijuana-frequency  cocaine-use  cocaine-frequency  crack-use  \
# 7                 60.0          4.1                5.5        0.5
# 8                 60.0          4.9                8.0        0.6
# 9                 52.0          4.8                5.0        0.5
#
#    crack-frequency         ...          oxycontin-use  oxycontin-frequency  \
# 7              2.0         ...                    1.5                  7.5
# 8              5.0         ...                    1.7                 12.0
# 9             17.0         ...                    1.3                 13.5
#
#    tranquilizer-use  tranquilizer-frequency  stimulant-use  \
# 7               4.2                     4.5            3.3
# ...

# %%
narko[3:]
# Out:
#       age     n  alcohol-use  alcohol-frequency  marijuana-use  \
# 3      15  2956         29.2                6.0           14.5
# 4      16  3058         40.1               10.0           22.5
# 5      17  3038         49.3               13.0           28.0
# 6      18  2469         58.7               24.0           33.7
# 7      19  2223         64.6               36.0           33.4
# 8      20  2271         69.7               48.0           34.0
# 9      21  2354         83.2               52.0           33.0
# 10  22-23  4707         84.2               52.0           28.4
# 11  24-25  4591         83.1               52.0           24.9
# 12  26-29  2628         80.7               52.0           20.8
# 13  30-34  2864         77.5               52.0           16.4
# 14  35-49  7391         75.0               52.0           10.4
# 15  50-64  3923         67.2               52.0            7.3
# 16    65+  2448         49.3               52.0            1.2
#
# ...

# %%
narko[3:-1]
# Out:
#       age     n  alcohol-use  alcohol-frequency  marijuana-use  \
# 3      15  2956         29.2                6.0           14.5
# 4      16  3058         40.1               10.0           22.5
# 5      17  3038         49.3               13.0           28.0
# 6      18  2469         58.7               24.0           33.7
# 7      19  2223         64.6               36.0           33.4
# 8      20  2271         69.7               48.0           34.0
# 9      21  2354         83.2               52.0           33.0
# 10  22-23  4707         84.2               52.0           28.4
# 11  24-25  4591         83.1               52.0           24.9
# 12  26-29  2628         80.7               52.0           20.8
# 13  30-34  2864         77.5               52.0           16.4
# 14  35-49  7391         75.0               52.0           10.4
# 15  50-64  3923         67.2               52.0            7.3
#
#     marijuana-frequency  cocaine-use  cocaine-frequency  crack-use  \
# ...

# %%
narko[-7:]
# Out:
#       age     n  alcohol-use  alcohol-frequency  marijuana-use  \
# 10  22-23  4707         84.2               52.0           28.4
# 11  24-25  4591         83.1               52.0           24.9
# 12  26-29  2628         80.7               52.0           20.8
# 13  30-34  2864         77.5               52.0           16.4
# 14  35-49  7391         75.0               52.0           10.4
# 15  50-64  3923         67.2               52.0            7.3
# 16    65+  2448         49.3               52.0            1.2
#
#     marijuana-frequency  cocaine-use  cocaine-frequency  crack-use  \
# 10                 52.0          4.5                5.0        0.5
# 11                 60.0          4.0                6.0        0.5
# 12                 52.0          3.2                5.0        0.4
# 13                 72.0          2.1                8.0        0.5
# 14                 48.0          1.5               15.0        0.5
# ...

# %%
narko[:-6]
# Out:
#       age     n  alcohol-use  alcohol-frequency  marijuana-use  \
# 0      12  2798          3.9                3.0            1.1
# 1      13  2757          8.5                6.0            3.4
# 2      14  2792         18.1                5.0            8.7
# 3      15  2956         29.2                6.0           14.5
# 4      16  3058         40.1               10.0           22.5
# 5      17  3038         49.3               13.0           28.0
# 6      18  2469         58.7               24.0           33.7
# 7      19  2223         64.6               36.0           33.4
# 8      20  2271         69.7               48.0           34.0
# 9      21  2354         83.2               52.0           33.0
# 10  22-23  4707         84.2               52.0           28.4
#
#     marijuana-frequency  cocaine-use  cocaine-frequency  crack-use  \
# 0                   4.0          0.1                5.0        0.0
# 1                  15.0          0.1                1.0        0.0
# ...

# %%
narko[11:2:-1]
# Out:
#       age     n  alcohol-use  alcohol-frequency  marijuana-use  \
# 11  24-25  4591         83.1               52.0           24.9
# 10  22-23  4707         84.2               52.0           28.4
# 9      21  2354         83.2               52.0           33.0
# 8      20  2271         69.7               48.0           34.0
# 7      19  2223         64.6               36.0           33.4
# 6      18  2469         58.7               24.0           33.7
# 5      17  3038         49.3               13.0           28.0
# 4      16  3058         40.1               10.0           22.5
# 3      15  2956         29.2                6.0           14.5
#
#     marijuana-frequency  cocaine-use  cocaine-frequency  crack-use  \
# 11                 60.0          4.0                6.0        0.5
# 10                 52.0          4.5                5.0        0.5
# 9                  52.0          4.8                5.0        0.5
# ...

# %%
narko['age']
# Out:
# 0        12
# 1        13
# 2        14
# 3        15
# 4        16
# 5        17
# 6        18
# 7        19
# 8        20
# 9        21
# 10    22-23
# 11    24-25
# 12    26-29
# 13    30-34
# 14    35-49
# 15    50-64
# 16      65+
# Name: age, dtype: object

# %%
narko['n']
# Out:
# 0     2798
# 1     2757
# 2     2792
# 3     2956
# 4     3058
# 5     3038
# 6     2469
# 7     2223
# 8     2271
# 9     2354
# 10    4707
# 11    4591
# 12    2628
# 13    2864
# 14    7391
# 15    3923
# 16    2448
# Name: n, dtype: int64

# %%
narko['n'].sum()
# Out:
# 55268

# %%
narko['n'].mean()
# Out:
# 3251.0588235294117

# %%
narko['n'].std()
# Out:
# 1297.8904263548327

# %%
narko['cocaine-use'].max()
# Out:
# 4.9

# %%
narko['cocaine-use'].idxmax()
# Out:
# 8

# %%
indeks = narko['cocaine-use'].idxmax()

# %%
narko[indeks:indeks+1]
# Out:
#   age     n  alcohol-use  alcohol-frequency  marijuana-use  \
# 8  20  2271         69.7               48.0           34.0
#
#    marijuana-frequency  cocaine-use  cocaine-frequency  crack-use  \
# 8                 60.0          4.9                8.0        0.6
#
#    crack-frequency         ...          oxycontin-use  oxycontin-frequency  \
# 8              5.0         ...                    1.7                 12.0
#
#    tranquilizer-use  tranquilizer-frequency  stimulant-use  \
# 8               5.4                    10.0            4.0
#
#    stimulant-frequency  meth-use  meth-frequency  sedative-use  \
# 8                 12.0       0.9            12.0           0.5
#
#    sedative-frequency
# 8                 4.0
#
# [1 rows x 28 columns]

# %%
narko.iloc[8, 1]
# Out:
# 2271

# %%
narko.iloc[8, 0:3]
# Out:
# age              20
# n              2271
# alcohol-use    69.7
# Name: 8, dtype: object

# %%
narko.iloc[8:10, 0:3]
# Out:
#   age     n  alcohol-use
# 8  20  2271         69.7
# 9  21  2354         83.2

# %%
narko.iloc[[1, 3, 8], [2, 6, 14]]
# Out:
#    alcohol-use  cocaine-use  inhalant-use
# 1          8.5          0.1           2.5
# 3         29.2          0.5           2.5
# 8         69.7          4.9           1.5

# %%
narko.iloc[::2, 2:4]
# Out:
#     alcohol-use  alcohol-frequency
# 0           3.9                3.0
# 2          18.1                5.0
# 4          40.1               10.0
# 6          58.7               24.0
# 8          69.7               48.0
# 10         84.2               52.0
# 12         80.7               52.0
# 14         75.0               52.0
# 16         49.3               52.0

# %%
narko.iloc[::2, 2:4].mean()
# Out:
# alcohol-use          53.300000
# alcohol-frequency    33.111111
# dtype: float64

# %%
narko.mean()
# Out:
# n                          3251.058824
# alcohol-use                  55.429412
# alcohol-frequency            33.352941
# marijuana-use                18.923529
# marijuana-frequency          42.941176
# cocaine-use                   2.176471
# cocaine-frequency             7.875000
# crack-use                     0.294118
# crack-frequency              15.035714
# heroin-use                    0.352941
# heroin-frequency             73.281250
# hallucinogen-use              3.394118
# hallucinogen-frequency        8.411765
# inhalant-use                  1.388235
# inhalant-frequency            6.156250
# pain-releiver-use             6.270588
# pain-releiver-frequency      14.705882
# oxycontin-use                 0.935294
# oxycontin-frequency          14.812500
# tranquilizer-use              2.805882
# tranquilizer-frequency       11.735294
# stimulant-use                 1.917647
# stimulant-frequency          31.147059
# meth-use                      0.382353
# ...

# %%
narko.iloc[:, 2::2].mean()
# Out:
# alcohol-use          55.429412
# marijuana-use        18.923529
# cocaine-use           2.176471
# crack-use             0.294118
# heroin-use            0.352941
# hallucinogen-use      3.394118
# inhalant-use          1.388235
# pain-releiver-use     6.270588
# oxycontin-use         0.935294
# tranquilizer-use      2.805882
# stimulant-use         1.917647
# meth-use              0.382353
# sedative-use          0.282353
# dtype: float64

# %%
narko.iloc[:, 2::2].std()
# Out:
# alcohol-use          26.878866
# marijuana-use        11.959752
# cocaine-use           1.816772
# crack-use             0.235772
# heroin-use            0.333762
# hallucinogen-use      2.792506
# inhalant-use          0.927283
# pain-releiver-use     3.166379
# oxycontin-use         0.608216
# tranquilizer-use      1.753379
# stimulant-use         1.407673
# meth-use              0.262762
# sedative-use          0.138000
# dtype: float64

# %%
narko.iloc[:, 2::2].max()
# Out:
# alcohol-use          84.2
# marijuana-use        34.0
# cocaine-use           4.9
# crack-use             0.6
# heroin-use            1.1
# hallucinogen-use      8.6
# inhalant-use          3.0
# pain-releiver-use    10.0
# oxycontin-use         1.7
# tranquilizer-use      5.4
# stimulant-use         4.1
# meth-use              0.9
# sedative-use          0.5
# dtype: float64

# %%
narko.iloc[:, 2::2].max().sort_values()
# Out:
# sedative-use          0.5
# crack-use             0.6
# meth-use              0.9
# heroin-use            1.1
# oxycontin-use         1.7
# inhalant-use          3.0
# stimulant-use         4.1
# cocaine-use           4.9
# tranquilizer-use      5.4
# hallucinogen-use      8.6
# pain-releiver-use    10.0
# marijuana-use        34.0
# alcohol-use          84.2
# dtype: float64

# %%
narko['hallucinogen-use'].idxmax()
# Out:
# 7

# %%
narko.iloc(narko['hallucinogen-use'].idxmax(), :)
# Out:
#   File "<ipython-input-73-eab9e1ff389f>", line 1
#     narko.iloc(narko['hallucinogen-use'].idxmax(), :)
#                                                    ^
# SyntaxError: invalid syntax
